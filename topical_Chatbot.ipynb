# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Install Transformers library
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 66.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 82.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.0

# %%
# Import necessary libraries
import os
import json
import string
import re
import torch
import random
import numpy as np
from transformers import GPT2LMHeadModel, GPT2Tokenizer, AdamW, get_linear_schedule_with_warmup
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Load the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# Set up the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# Load your conversational dataset
def load_dataset(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

data = load_dataset('/content/sample_data/anscombe.json')

# %%
# Data Preprocessing
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

preprocessed_data = []

for conversation in data:
    preprocessed_conversation = []

    for message in conversation:
        preprocessed_message = preprocess_text(message)
        preprocessed_conversation.append(preprocessed_message)

    preprocessed_data.append(preprocessed_conversation)

# %%
# Split data into training, validation, and test sets
random.seed(42)  # Set a random seed for reproducibility
train_ratio = 0.7  # Adjust the ratio as needed
val_ratio = 0.15
test_ratio = 0.15

total_conversations = len(preprocessed_data)
train_size = int(train_ratio * total_conversations)
val_size = int(val_ratio * total_conversations)
test_size = total_conversations - train_size - val_size

train_data, val_data, test_data = random_split(preprocessed_data, [train_size, val_size, test_size])

# %%
# Training Data Preparation
train_text = ""
val_text = ""
test_text = ""

for conversation in train_data:
    train_text += " ".join(conversation) + " "

for conversation in val_data:
    val_text += " ".join(conversation) + " "

for conversation in test_data:
    test_text += " ".join(conversation) + " "

# %%
# Tokenize and encode the training, validation, and test text
train_input_ids = tokenizer.encode(train_text, return_tensors="pt", max_length=512, truncation=True).to(device)
val_input_ids = tokenizer.encode(val_text, return_tensors="pt", max_length=512, truncation=True).to(device)
test_input_ids = tokenizer.encode(test_text, return_tensors="pt", max_length=512, truncation=True).to(device)

# %%
# Define the training parameters
learning_rate = 1e-4
epochs = 200
batch_size = 2  # Adjust batch size according to your hardware

# %%
# Create data loaders
train_data = torch.utils.data.TensorDataset(train_input_ids)
val_data = torch.utils.data.TensorDataset(val_input_ids)
test_data = torch.utils.data.TensorDataset(test_input_ids)

train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

# %%
# Set up optimizer and scheduler
optimizer = AdamW(model.parameters(), lr=learning_rate)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=len(train_dataloader) * epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Add these lines at the beginning to import the necessary modules
from torch.utils.tensorboard import SummaryWriter

# Create a TensorBoard writer
writer = SummaryWriter()

# %%
# Training Loop
model.train()
for epoch in range(epochs):
    total_loss = 0.0
    for batch in train_dataloader:
        inputs = batch[0].to(device)
        labels = inputs.clone()

        optimizer.zero_grad()
        outputs = model(inputs, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        scheduler.step()

        total_loss += loss.item()

    average_loss = total_loss / len(train_dataloader)
    print(f"Epoch {epoch+1}/{epochs} - Average Loss: {average_loss:.4f}")

    # Log loss to TensorBoard
    writer.add_scalar('Loss/Train', average_loss, epoch)
# Out:
# Epoch 1/200 - Average Loss: 0.8586
# Epoch 2/200 - Average Loss: 3.1682
# Epoch 3/200 - Average Loss: 0.5095
# Epoch 4/200 - Average Loss: 0.4272
# Epoch 5/200 - Average Loss: 0.3496
# Epoch 6/200 - Average Loss: 0.2780
# Epoch 7/200 - Average Loss: 0.2161
# Epoch 8/200 - Average Loss: 0.2052
# Epoch 9/200 - Average Loss: 0.2316
# Epoch 10/200 - Average Loss: 0.2717
# Epoch 11/200 - Average Loss: 0.1000
# Epoch 12/200 - Average Loss: 0.1317
# Epoch 13/200 - Average Loss: 0.0782
# Epoch 14/200 - Average Loss: 0.1466
# Epoch 15/200 - Average Loss: 0.0700
# Epoch 16/200 - Average Loss: 0.1206
# Epoch 17/200 - Average Loss: 0.0347
# Epoch 18/200 - Average Loss: 0.1460
# Epoch 19/200 - Average Loss: 0.0405
# Epoch 20/200 - Average Loss: 0.1241
# Epoch 21/200 - Average Loss: 0.1141
# Epoch 22/200 - Average Loss: 0.0352
# Epoch 23/200 - Average Loss: 0.1268
# Epoch 24/200 - Average Loss: 0.0644
# Epoch 25/200 - Average Loss: 0.0400
# Epoch 26/200 - Average Loss: 0.0341
# Epoch 27/200 - Average Loss: 0.0544
# Epoch 28/200 - Average Loss: 0.0415
# Epoch 29/200 - Average Loss: 0.0439
# Epoch 30/200 - Average Loss: 0.0245
# Epoch 31/200 - Average Loss: 0.0219
# Epoch 32/200 - Average Loss: 0.0639
# Epoch 33/200 - Average Loss: 0.1227
# Epoch 34/200 - Average Loss: 0.0725
# Epoch 35/200 - Average Loss: 0.0310
# Epoch 36/200 - Average Loss: 0.1433
# Epoch 37/200 - Average Loss: 0.0417
# Epoch 38/200 - Average Loss: 0.0498
# Epoch 39/200 - Average Loss: 0.0269
# Epoch 40/200 - Average Loss: 0.0165
# Epoch 41/200 - Average Loss: 0.0254
# Epoch 42/200 - Average Loss: 0.1144
# Epoch 43/200 - Average Loss: 0.0607
# Epoch 44/200 - Average Loss: 0.1013
# Epoch 45/200 - Average Loss: 0.1210
# Epoch 46/200 - Average Loss: 0.1432
# Epoch 47/200 - Average Loss: 0.0669
# Epoch 48/200 - Average Loss: 0.0305
# Epoch 49/200 - Average Loss: 0.1021
# Epoch 50/200 - Average Loss: 0.1078
# Epoch 51/200 - Average Loss: 0.0373
# Epoch 52/200 - Average Loss: 0.0458
# Epoch 53/200 - Average Loss: 0.0545
# Epoch 54/200 - Average Loss: 0.0406
# Epoch 55/200 - Average Loss: 0.0350
# Epoch 56/200 - Average Loss: 0.1284
# Epoch 57/200 - Average Loss: 0.1235
# Epoch 58/200 - Average Loss: 0.0928
# Epoch 59/200 - Average Loss: 0.0310
# Epoch 60/200 - Average Loss: 0.0214
# Epoch 61/200 - Average Loss: 0.0286
# Epoch 62/200 - Average Loss: 0.0952
# Epoch 63/200 - Average Loss: 0.0488
# Epoch 64/200 - Average Loss: 0.0261
# Epoch 65/200 - Average Loss: 0.0223
# Epoch 66/200 - Average Loss: 0.1100
# Epoch 67/200 - Average Loss: 0.0544
# Epoch 68/200 - Average Loss: 0.1123
# Epoch 69/200 - Average Loss: 0.0383
# Epoch 70/200 - Average Loss: 0.0441
# Epoch 71/200 - Average Loss: 0.0178
# Epoch 72/200 - Average Loss: 0.0378
# Epoch 73/200 - Average Loss: 0.0237
# Epoch 74/200 - Average Loss: 0.0203
# Epoch 75/200 - Average Loss: 0.0161
# Epoch 76/200 - Average Loss: 0.0279
# Epoch 77/200 - Average Loss: 0.0155
# Epoch 78/200 - Average Loss: 0.0970
# Epoch 79/200 - Average Loss: 0.1116
# Epoch 80/200 - Average Loss: 0.0309
# Epoch 81/200 - Average Loss: 0.1070
# Epoch 82/200 - Average Loss: 0.0315
# Epoch 83/200 - Average Loss: 0.0167
# Epoch 84/200 - Average Loss: 0.0993
# Epoch 85/200 - Average Loss: 0.0292
# Epoch 86/200 - Average Loss: 0.1008
# Epoch 87/200 - Average Loss: 0.0154
# Epoch 88/200 - Average Loss: 0.0133
# Epoch 89/200 - Average Loss: 0.0219
# Epoch 90/200 - Average Loss: 0.0093
# Epoch 91/200 - Average Loss: 0.0486
# Epoch 92/200 - Average Loss: 0.0405
# Epoch 93/200 - Average Loss: 0.0263
# Epoch 94/200 - Average Loss: 0.0361
# Epoch 95/200 - Average Loss: 0.0173
# Epoch 96/200 - Average Loss: 0.0837
# Epoch 97/200 - Average Loss: 0.0302
# Epoch 98/200 - Average Loss: 0.0289
# Epoch 99/200 - Average Loss: 0.0123
# Epoch 100/200 - Average Loss: 0.0146
# Epoch 101/200 - Average Loss: 0.0319
# Epoch 102/200 - Average Loss: 0.1088
# Epoch 103/200 - Average Loss: 0.0139
# Epoch 104/200 - Average Loss: 0.0097
# Epoch 105/200 - Average Loss: 0.0201
# Epoch 106/200 - Average Loss: 0.1065
# Epoch 107/200 - Average Loss: 0.0299
# Epoch 108/200 - Average Loss: 0.0094
# Epoch 109/200 - Average Loss: 0.0375
# Epoch 110/200 - Average Loss: 0.0178
# Epoch 111/200 - Average Loss: 0.0173
# Epoch 112/200 - Average Loss: 0.0120
# Epoch 113/200 - Average Loss: 0.0155
# Epoch 114/200 - Average Loss: 0.0301
# Epoch 115/200 - Average Loss: 0.0066
# Epoch 116/200 - Average Loss: 0.0072
# Epoch 117/200 - Average Loss: 0.0101
# Epoch 118/200 - Average Loss: 0.0306
# Epoch 119/200 - Average Loss: 0.0222
# Epoch 120/200 - Average Loss: 0.0349
# Epoch 121/200 - Average Loss: 0.0128
# Epoch 122/200 - Average Loss: 0.0909
# Epoch 123/200 - Average Loss: 0.0218
# Epoch 124/200 - Average Loss: 0.0692
# Epoch 125/200 - Average Loss: 0.0339
# Epoch 126/200 - Average Loss: 0.0061
# Epoch 127/200 - Average Loss: 0.0577
# Epoch 128/200 - Average Loss: 0.0451
# Epoch 129/200 - Average Loss: 0.1150
# Epoch 130/200 - Average Loss: 0.0334
# Epoch 131/200 - Average Loss: 0.0734
# Epoch 132/200 - Average Loss: 0.1016
# Epoch 133/200 - Average Loss: 0.0588
# Epoch 134/200 - Average Loss: 0.0356
# Epoch 135/200 - Average Loss: 0.0161
# Epoch 136/200 - Average Loss: 0.0217
# Epoch 137/200 - Average Loss: 0.0189
# Epoch 138/200 - Average Loss: 0.2012
# Epoch 139/200 - Average Loss: 0.0063
# Epoch 140/200 - Average Loss: 0.0086
# Epoch 141/200 - Average Loss: 0.0025
# Epoch 142/200 - Average Loss: 0.0538
# Epoch 143/200 - Average Loss: 0.0447
# Epoch 144/200 - Average Loss: 0.0332
# Epoch 145/200 - Average Loss: 0.0493
# Epoch 146/200 - Average Loss: 0.0311
# Epoch 147/200 - Average Loss: 0.0748
# Epoch 148/200 - Average Loss: 0.0136
# Epoch 149/200 - Average Loss: 0.0186
# Epoch 150/200 - Average Loss: 0.0205
# Epoch 151/200 - Average Loss: 0.0123
# Epoch 152/200 - Average Loss: 0.0948
# Epoch 153/200 - Average Loss: 0.0900
# Epoch 154/200 - Average Loss: 0.0830
# Epoch 155/200 - Average Loss: 0.0120
# Epoch 156/200 - Average Loss: 0.0139
# Epoch 157/200 - Average Loss: 0.0183
# Epoch 158/200 - Average Loss: 0.0868
# Epoch 159/200 - Average Loss: 0.0057
# Epoch 160/200 - Average Loss: 0.0245
# Epoch 161/200 - Average Loss: 0.0226
# Epoch 162/200 - Average Loss: 0.0916
# Epoch 163/200 - Average Loss: 0.0140
# Epoch 164/200 - Average Loss: 0.0152
# Epoch 165/200 - Average Loss: 0.0220
# Epoch 166/200 - Average Loss: 0.0169
# Epoch 167/200 - Average Loss: 0.0079
# Epoch 168/200 - Average Loss: 0.0211
# Epoch 169/200 - Average Loss: 0.0084
# Epoch 170/200 - Average Loss: 0.0948
# Epoch 171/200 - Average Loss: 0.0091
# Epoch 172/200 - Average Loss: 0.0088
# Epoch 173/200 - Average Loss: 0.0103
# Epoch 174/200 - Average Loss: 0.0844
# Epoch 175/200 - Average Loss: 0.0578
# Epoch 176/200 - Average Loss: 0.0080
# Epoch 177/200 - Average Loss: 0.0123
# Epoch 178/200 - Average Loss: 0.0111
# Epoch 179/200 - Average Loss: 0.0514
# Epoch 180/200 - Average Loss: 0.0197
# Epoch 181/200 - Average Loss: 0.0786
# Epoch 182/200 - Average Loss: 0.0130
# Epoch 183/200 - Average Loss: 0.0119
# Epoch 184/200 - Average Loss: 0.0088
# Epoch 185/200 - Average Loss: 0.0177
# Epoch 186/200 - Average Loss: 0.0071
# Epoch 187/200 - Average Loss: 0.0151
# Epoch 188/200 - Average Loss: 0.0046
# Epoch 189/200 - Average Loss: 0.0812
# Epoch 190/200 - Average Loss: 0.0151
# Epoch 191/200 - Average Loss: 0.0287
# Epoch 192/200 - Average Loss: 0.0115
# Epoch 193/200 - Average Loss: 0.0098
# Epoch 194/200 - Average Loss: 0.0936
# Epoch 195/200 - Average Loss: 0.0164
# Epoch 196/200 - Average Loss: 0.0855
# Epoch 197/200 - Average Loss: 0.0808
# Epoch 198/200 - Average Loss: 0.0776
# Epoch 199/200 - Average Loss: 0.0110
# Epoch 200/200 - Average Loss: 0.0079

# %%
def generate_response(input_text, max_length=100):
    input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)  # Ensure input_ids is on the same device as the model

    # Generate a response
    response_ids = model.generate(input_ids, max_length=max_length, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id)

    # Decode and return the response
    response = tokenizer.decode(response_ids[0], skip_special_tokens=True)
    return response

# %%
# Example conversation
user_input = "Hello, how are you?"
conversation_history = []

while True:
    user_input = input("User: ")

    # Append the user's input to the conversation history
    conversation_history.append(user_input)

    # Generate a response based on the entire conversation history
    bot_response = generate_response(" ".join(conversation_history))
    print("Bot:", bot_response)

    # Optionally, you can add logic to end the conversation (e.g., "exit" command)
    if user_input.lower() == "exit":
        break
# Out:
# User: Hello, how are you?
# Bot: Hello, how are you?
#
# I'm a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy who is a guy
# User: exit
# Bot: Hello, how are you? exit code x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y series x y   y
